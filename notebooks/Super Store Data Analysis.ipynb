# %% [markdown]
# # Super Store Data Analysis
# ## Satya Pati

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('..\datasets\SampleSuperstore.csv')

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
# Dropping country as it has no use.
df.drop('Country', axis=1, inplace=True)

# %%
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
df['City'].value_counts()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Norfolk            1
# Keller             1
# Cheyenne           1
# Aberdeen           1
# Chapel Hill        1
# Name: City, Length: 531, dtype: int64

# %%
df['Postal Code'] = df['Postal Code'].astype('str')
df['Postal Code'].value_counts()
# Out:
# 10035    263
# 10024    230
# 10009    229
# 94122    203
# 10011    193
#         ...
# 82001      1
# 11757      1
# 1040       1
# 50701      1
# 95610      1
# Name: Postal Code, Length: 631, dtype: int64

# %%
# dropping postal code
df.drop('Postal Code', axis=1, inplace=True)

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
df[['Sales','Quantity','Discount','Profit']].describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
ship_mode_tot = df[['Ship Mode','Sales', 'Quantity', 'Discount', 'Profit']].groupby('Ship Mode').sum()
ship_mode_avg = df[['Ship Mode','Sales', 'Quantity', 'Discount', 'Profit']].groupby('Ship Mode').mean()

# %%
ship_mode_avg
# Out:
#                      Sales  Quantity  Discount     Profit
# Ship Mode
# First Class     228.497024  3.701560  0.164610  31.839948
# Same Day        236.396179  3.609576  0.152394  29.266591
# Second Class    236.089239  3.816452  0.138895  29.535545
# Standard Class  227.583067  3.819873  0.160023  27.494770

# %%
ship_mode_tot['Sales'] = np.round(ship_mode_tot['Sales'], 2)
ship_mode_tot
# Out:
#                      Sales  Quantity  Discount       Profit
# Ship Mode
# First Class      351428.42      5693    253.17   48969.8399
# Same Day         128363.12      1960     82.75   15891.7589
# Second Class     459193.57      7423    270.15   57446.6354
# Standard Class  1358215.74     22797    955.02  164088.7875

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'City', 'State', 'Region', 'Category',
#        'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
segment_tot = df[['Segment','Sales', 'Quantity', 'Discount', 'Profit']].groupby('Segment').sum()
segment_avg = df[['Segment','Sales', 'Quantity', 'Discount', 'Profit']].groupby('Segment').mean()
segment_tot['Sales'] = np.round(segment_tot['Sales'], 2)

# %%
segment_tot
# Out:
#                   Sales  Quantity  Discount       Profit
# Segment
# Consumer     1161401.34     19521    820.91  134119.2092
# Corporate     706146.37     11608    477.85   91979.1340
# Home Office   429653.15      6744    262.33   60298.6785

# %%
segment_avg
# Out:
#                   Sales  Quantity  Discount     Profit
# Segment
# Consumer     223.733644  3.760547  0.158141  25.836873
# Corporate    233.823300  3.843709  0.158228  30.456667
# Home Office  240.972041  3.782389  0.147128  33.818664

# %%
city_tot = df[['City','Sales', 'Quantity', 'Discount', 'Profit']].groupby('City').sum()
city_avg = df[['City','Sales', 'Quantity', 'Discount', 'Profit']].groupby('City').mean()
# segment_tot['Sales'] = np.round(segment_tot['Sales'], 2)

# %%
city_tot
# Out:
#                 Sales  Quantity  Discount     Profit
# City
# Aberdeen       25.500         3       0.0     6.6300
# Abilene         1.392         2       0.8    -3.7584
# Akron        2729.986        65       7.5  -186.6356
# Albuquerque  2220.160        65       0.8   634.0881
# Alexandria   5519.570        84       0.0   318.6183
# ...               ...       ...       ...        ...
# Woonsocket    195.550        15       0.0    78.6791
# Yonkers      7657.666        57       1.0  2767.7557
# York          817.978        19       2.1  -102.1692
# Yucaipa        50.800         5       0.0    13.2080
# Yuma          840.865        22       1.8  -465.9909
#
# [531 rows x 4 columns]

# %%
city_avg
# Out:
#                   Sales  Quantity  Discount      Profit
# City
# Aberdeen      25.500000  3.000000  0.000000    6.630000
# Abilene        1.392000  2.000000  0.800000   -3.758400
# Akron        129.999333  3.095238  0.357143   -8.887410
# Albuquerque  158.582857  4.642857  0.057143   45.292007
# Alexandria   344.973125  5.250000  0.000000   19.913644
# ...                 ...       ...       ...         ...
# Woonsocket    48.887500  3.750000  0.000000   19.669775
# Yonkers      510.511067  3.800000  0.066667  184.517047
# York         163.595600  3.800000  0.420000  -20.433840
# Yucaipa       50.800000  5.000000  0.000000   13.208000
# Yuma         210.216250  5.500000  0.450000 -116.497725
#
# [531 rows x 4 columns]

# %%
state_tot = df[['State','Sales', 'Quantity', 'Discount', 'Profit']].groupby('State').sum()
state_avg = df[['State','Sales', 'Quantity', 'Discount', 'Profit']].groupby('State').mean()
# segment_tot['Sales'] = np.round(segment_tot['Sales'], 2)

# %%
state_tot
# Out:
#                             Sales  Quantity  Discount      Profit
# State
# Alabama                19510.6400       256      0.00   5786.8253
# Arizona                35282.0010       862     68.00  -3427.9246
# Arkansas               11678.1300       240      0.00   4008.6871
# California            457687.6315      7667    145.60  76381.3871
# Colorado               32108.1180       693     57.60  -6527.8579
# Connecticut            13384.3570       281      0.60   3511.4918
# Delaware               27451.0690       367      0.60   9977.3748
# District of Columbia    2865.0200        40      0.00   1059.5893
# Florida                89473.7080      1379    114.65  -3399.3017
# Georgia                49095.8400       705      0.00  16250.0433
# Idaho                   4382.4860        64      1.80    826.7231
# Illinois               80166.1010      1845    191.90 -12607.8870
# Indiana                53555.3600       578      0.00  18382.9363
# ...

# %%
state_avg
# Out:
#                             Sales  Quantity  Discount      Profit
# State
# Alabama                319.846557  4.196721  0.000000   94.865989
# Arizona                157.508933  3.848214  0.303571  -15.303235
# Arkansas               194.635500  4.000000  0.000000   66.811452
# California             228.729451  3.831584  0.072764   38.171608
# Colorado               176.418231  3.807692  0.316484  -35.867351
# Connecticut            163.223866  3.426829  0.007317   42.823071
# Delaware               285.948635  3.822917  0.006250  103.930988
# District of Columbia   286.502000  4.000000  0.000000  105.958930
# Florida                233.612815  3.600522  0.299347   -8.875461
# Georgia                266.825217  3.831522  0.000000   88.315453
# Idaho                  208.689810  3.047619  0.085714   39.367767
# Illinois               162.939230  3.750000  0.390041  -25.625787
# Indiana                359.431946  3.879195  0.000000  123.375411
# ...

# %%
region_tot = df[['Region','Sales', 'Quantity', 'Discount', 'Profit']].groupby('Region').sum()
region_avg = df[['Region','Sales', 'Quantity', 'Discount', 'Profit']].groupby('Region').mean()
# segment_tot['Sales'] = np.round(segment_tot['Sales'], 2)

# %%
region_tot
# Out:
#                Sales  Quantity  Discount       Profit
# Region
# Central  501239.8908      8780    558.34   39706.3625
# East     678781.2400     10618    414.00   91522.7800
# South    391721.9050      6209    238.55   46749.4303
# West     725457.8245     12266    350.20  108418.4489

# %%
region_avg
# Out:
#               Sales  Quantity  Discount     Profit
# Region
# Central  215.772661  3.779595  0.240353  17.092709
# East     238.336110  3.728230  0.145365  32.135808
# South    241.803645  3.832716  0.147253  28.857673
# West     226.493233  3.829535  0.109335  33.849032

# %%
cat_tot = df[['Category','Sales', 'Quantity', 'Discount', 'Profit']].groupby('Category').sum()
cat_avg = df[['Category','Sales', 'Quantity', 'Discount', 'Profit']].groupby('Category').mean()
# segment_tot['Sales'] = np.round(segment_tot['Sales'], 2)

# %%
cat_tot
# Out:
#                        Sales  Quantity  Discount       Profit
# Category
# Furniture        741999.7953      8028    368.89   18451.2728
# Office Supplies  719047.0320     22906    947.80  122490.8008
# Technology       836154.0330      6939    244.40  145454.9481

# %%
cat_avg
# Out:
#                       Sales  Quantity  Discount     Profit
# Category
# Furniture        349.834887  3.785007  0.173923   8.699327
# Office Supplies  119.324101  3.801195  0.157285  20.327050
# Technology       452.709276  3.756903  0.132323  78.752002

# %%
subcat_tot = df[['Sub-Category','Sales', 'Quantity', 'Discount', 'Profit']].groupby('Sub-Category').sum()
subcat_avg = df[['Sub-Category','Sales', 'Quantity', 'Discount', 'Profit']].groupby('Sub-Category').mean()

# %%
subcat_tot
# Out:
#                     Sales  Quantity  Discount      Profit
# Sub-Category
# Accessories   167380.3180      2976     60.80  41936.6357
# Appliances    107532.1610      1729     77.60  18138.0054
# Art            27118.7920      3000     59.60   6527.7870
# Binders       203412.7330      5974    567.00  30221.7633
# Bookcases     114879.9963       868     48.14  -3472.5560
# Chairs        328449.1030      2356    105.00  26590.1663
# Copiers       149528.0300       234     11.00  55617.8249
# Envelopes      16476.4020       906     20.40   6964.1767
# Fasteners       3024.2800       914     17.80    949.5182
# Furnishings    91705.1640      3563    132.40  13059.1436
# Labels         12486.3120      1400     25.00   5546.2540
# Machines      189238.6310       440     35.20   3384.7569
# Paper          78479.2060      5178    102.60  34053.5693
# Phones        330007.0540      3289    137.40  44515.7306
# Storage       223843.6080      3158     63.20  21278.8264
# ...

# %%
subcat_avg
# Out:
#                     Sales  Quantity  Discount      Profit
# Sub-Category
# Accessories    215.974604  3.840000  0.078452   54.111788
# Appliances     230.755710  3.710300  0.166524   38.922758
# Art             34.068834  3.768844  0.074874    8.200737
# Binders        133.560560  3.922521  0.372292   19.843574
# Bookcases      503.859633  3.807018  0.211140  -15.230509
# Chairs         532.332420  3.818476  0.170178   43.095894
# Copiers       2198.941618  3.441176  0.161765  817.909190
# Envelopes       64.867724  3.566929  0.080315   27.418019
# Fasteners       13.936774  4.211982  0.082028    4.375660
# Furnishings     95.825668  3.723093  0.138349   13.645918
# Labels          34.303055  3.846154  0.068681   15.236962
# Machines      1645.553313  3.826087  0.306087   29.432669
# Paper           57.284092  3.779562  0.074891   24.856620
# Phones         371.211534  3.699663  0.154556   50.073938
# Storage        264.590553  3.732861  0.074704   25.152277
# ...
